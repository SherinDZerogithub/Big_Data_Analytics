# %%
import pandas as pd

# Load dataset
df = pd.read_csv('../data/Film_Dataset.csv')

# Display basic info
print("Original Dataset:")
print(df.head())
print("\nDataset Info:")
print(df.info())
print("\nMissing Values:")
print(df.isnull().sum())

# ====================
# 1. Data Cleaning
# ====================
df_clean = df.dropna(subset=['Film_Name', 'Language', 'Category', 'Viewing_Month'])

# Convert Viewing_Month to datetime
df_clean.loc[:, 'Viewing_Month'] = pd.to_datetime(df_clean['Viewing_Month'], errors='coerce')

# ====================
# 2. Filter for relevant time period
# ====================
cutoff_date = pd.to_datetime('2025-12-31')
df_clean = df_clean[df_clean['Viewing_Month'] <= cutoff_date]

# ====================
# 3. Handle duplicate movies with different languages/categories
# ====================
df_clean.loc[:, 'Unique_Movie'] = (
    df_clean['Film_Name'] + ' | ' +
    df_clean['Language'] + ' | ' +
    df_clean['Category']
)

# ====================
# 4. Viewing aggregation
# ====================
viewing_summary = df_clean.groupby(['Language', 'Category']).size().reset_index(name='View_Count')

# ====================
# 5. Save cleaned dataset
# ====================
df_clean.to_csv('../data/Film_Dataset_Cleaned.csv', index=False)

# ====================
# 6. Display cleaned info
# ====================
print("\n✅ Cleaned Dataset Info:")
print(df_clean.info())
print("\n✅ Cleaned Dataset Head:")
print(df_clean.head())
print("\n✅ Viewing Summary (Language & Category):")
print(viewing_summary)
# Out:
# Original Dataset:
#          Film_Name Release_Date     Category Language  Viewer_Rate  \
# 0  Chennai Express    9/12/2021      Romance    Hindi          4.5
# 1   Mountain Trail    4/27/2020       Comedy  English          3.5
# 2     Eternal Hope     7/4/2020      Romance  English          4.6
# 3  Seoul Heartbeat    4/17/2020       Comedy  English          4.1
# 4      Shadow Pact    2/24/2022  Documentary  English          4.3
#
#    Number_of_Views Viewing_Month
# 0            36395       2022-09
# 1            93162       2021-07
# 2            98663       2021-04
# 3           112635       2020-07
# 4            29496       2023-05
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film_Name        460 non-null    object
#  1   Release_Date     460 non-null    object
#  2   Category         460 non-null    object
#  3   Language         460 non-null    object
#  4   Viewer_Rate      460 non-null    float64
#  5   Number_of_Views  460 non-null    int64
#  6   Viewing_Month    460 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 25.3+ KB
# None
#
# Missing Values:
# Film_Name          0
# Release_Date       0
# Category           0
# Language           0
# Viewer_Rate        0
# Number_of_Views    0
# Viewing_Month      0
# dtype: int64
#
# ✅ Cleaned Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 445 entries, 0 to 459
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film_Name        445 non-null    object
#  1   Release_Date     445 non-null    object
#  2   Category         445 non-null    object
#  3   Language         445 non-null    object
#  4   Viewer_Rate      445 non-null    float64
#  5   Number_of_Views  445 non-null    int64
#  6   Viewing_Month    445 non-null    object
#  7   Unique_Movie     445 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 31.3+ KB
# None
#
# ✅ Cleaned Dataset Head:
#          Film_Name Release_Date     Category Language  Viewer_Rate  \
# 0  Chennai Express    9/12/2021      Romance    Hindi          4.5
# 1   Mountain Trail    4/27/2020       Comedy  English          3.5
# 2     Eternal Hope     7/4/2020      Romance  English          4.6
# 3  Seoul Heartbeat    4/17/2020       Comedy  English          4.1
# 4      Shadow Pact    2/24/2022  Documentary  English          4.3
#
#    Number_of_Views        Viewing_Month                         Unique_Movie
# 0            36395  2022-09-01 00:00:00    Chennai Express | Hindi | Romance
# 1            93162  2021-07-01 00:00:00    Mountain Trail | English | Comedy
# 2            98663  2021-04-01 00:00:00     Eternal Hope | English | Romance
# 3           112635  2020-07-01 00:00:00   Seoul Heartbeat | English | Comedy
# 4            29496  2023-05-01 00:00:00  Shadow Pact | English | Documentary
#
# ✅ Viewing Summary (Language & Category):
#    Language        Category  View_Count
# 0   Chinese   Action/Sci-Fi           9
# 1   Chinese          Comedy           9
# 2   Chinese     Documentary          11
# 3   Chinese  Drama/Thriller           6
# 4   Chinese          Horror           6
# ..      ...             ...         ...
# 64    Tamil          Comedy           7
# 65    Tamil     Documentary           9
# 66    Tamil  Drama/Thriller          13
# 67    Tamil          Horror          11
# 68    Tamil         Romance           8
#
# [69 rows x 3 columns]
